# %%
20/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-445153855.py in <cell line: 0>()
# ----> 1 20/0
#
# ZeroDivisionError: division by zero

# %%
try:
  a=10/0
  print(a)
except ZeroDivisionError:
  print("error:olungana value podu bro")
finally:
  print("varenda pulla")
# Out:
# error:olungana value podu bro
# varenda pulla

# %%
try:
  num=int(input("enter the number"))
  print(20/num)
except ZeroDivisionError:
  print("thapu:20 ah divide pandra number ah podu bro")
except ValueError:
  print("thiruthiko: number ah kudra vena ")
finally:
  print("varata mame")
# Out:
# enter the numberl
# thiruthiko: number ah kudra vena
# varata mame

# %%
try:
  num1=int(input("enter the value :"))
  num2=int(input("enter the value :"))
  answer=(num1/num2)
  print(answer)
except(ZeroDivisionError,ValueError):
  print("thapuda thambi,mathuda thambi")
# Out:
# enter the value :100
# enter the value :k
# thapuda thambi,mathuda thambi

# %%
atm=int(input("enter the value :"))
if atm>100000:
   raise ValueError("you exceed your daily limit")
else:
  print("widthdrawa your amt")
# Out:
# enter the value :200000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-717816268.py in <cell line: 0>()
#       1 atm=int(input("enter the value :"))
#       2 if atm>100000:
# ----> 3    raise ValueError("you exceed your daily limit")
#       4 else:
#       5   print("widthdrawa your amt")
#
# ValueError: you exceed your daily limit

# %%
try:
  print("s"+10)
except TypeError:
  print("error:str cannot be add to int")
# Out:
# error:str cannot be add to int

# %%
try:
  listvalue=["kural","amuthan","nishath","abi"]
  print(listvalue[7])
except IndexError:
  print("error:there is 4 index only")
# Out:
# error:there is 4 index only

# %%
try:
  num=int("seven")
  print(num)
except ValueError:
  print("error: cant convert str to int")
# Out:
# error: cant convert str to int

# %%
try:
  person={"name":"kural","age":23,"hostel":"yes"}
  print(person["kural"])
except KeyError:
  print("error: you asked the worng deatils")
# Out:
# error: you asked the worng deatils
